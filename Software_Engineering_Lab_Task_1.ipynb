# %% [markdown]
# <a href="https://colab.research.google.com/github/Anoop-1783/Software-Engineering/blob/main/Software_Engineering_Lab_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Hard-coded Variables for Weather Modeling
def temperature_modeling(a, b, c, time):
    temperature = a * time**2 + b * time + c
    return temperature
a_hardcoded, b_hardcoded, c_hardcoded = 4, 7, 3
print("Hard-coded Variables for Weather Modeling\n")
time_hardcoded = 5
print("Temperature for hardcoded coefficients at time", time_hardcoded, "hours:",
      temperature_modeling(a_hardcoded, b_hardcoded, c_hardcoded, time_hardcoded))
print("\n")
# Out:
# Hard-coded Variables for Weather Modeling
#
# Temperature for hardcoded coefficients at time 5 hours: 138

# %%
#Keyboard Input for Weather Modeling
def temperature_modeling(a, b, c, time):
    temperature = a * time**2 + b * time + c
    return temperature
print("Keyboard Input for Weather Modeling")
a_keyboard = float(input("Enter coefficient a: "))
b_keyboard = float(input("Enter coefficient b: "))
c_keyboard = float(input("Enter coefficient c: "))
time_keyboard = float(input("Enter time in hours: "))
print("Temperature for keyboard input coefficients at time", time_keyboard, "hours:",
      temperature_modeling(a_keyboard, b_keyboard, c_keyboard, time_keyboard))
print("\n")
# Out:
# Keyboard Input for Weather Modeling
# Enter coefficient a: 3
# Enter coefficient b: 2
# Enter coefficient c: 5
# Enter time in hours: 5
# Temperature for keyboard input coefficients at time 5.0 hours: 90.0

# %%
#Read from a File for Weather Modeling
def temperature_modeling(a, b, c, time):
    temperature = a * time**2 + b * time + c
    return temperature

with open("/content/weather1.txt", "r") as file:
    lines = file.readlines()
    a_file, b_file, c_file, time_file = map(float, lines[0].split())

print("Read from a File for Weather Modeling\n")
print("Temperature for file input coefficients at time", time_file, "hours:",
      temperature_modeling(a_file, b_file, c_file, time_file))
print("\n")
# Out:
# Read from a File for Weather Modeling
#
# Temperature for file input coefficients at time 3.0 hours: 66.0

# %%
#Multiple set User Input for Weather Modeling
import matplotlib.pyplot as plt
def temperature_modeling(a, b, c, time):
    temperature = a * time**2 + b * time + c
    return temperature
print("Multiple set User Input for Weather Modeling\n")
num_sets = int(input("Enter the number of sets of coefficients: "))
print("\n")
for _ in range(num_sets):
    coefficients = input("Enter coefficients (a, b, c) separated by spaces: ").split()
    a_user, b_user, c_user = map(float, coefficients)
    time_user = float(input("Enter time in hours: "))
    temperature_result = temperature_modeling(a_user, b_user, c_user, time_user)
    print("Temperature for user-input coefficients at time", time_user, "hours:", temperature_result)
    print("\n")
    time_values = range(int(time_user) + 1)
    temperature_values = [temperature_modeling(a_user, b_user, c_user, t) for t in time_values]
    plt.plot(time_values, temperature_values, label=f'Set {_ + 1}')

plt.xlabel('Time (hours)')
plt.ylabel('Temperature')
plt.title('Temperature Modeling for Multiple Sets')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Multiple set User Input for Weather Modeling
#
# Enter the number of sets of coefficients: 3
#
#
# Enter coefficients (a, b, c) separated by spaces: 2 2 2
# Enter time in hours: 5
# Temperature for user-input coefficients at time 5.0 hours: 62.0
#
#
# Enter coefficients (a, b, c) separated by spaces: 3 4 6
# Enter time in hours: 6
# Temperature for user-input coefficients at time 6.0 hours: 138.0
#
#
# Enter coefficients (a, b, c) separated by spaces: 4 6 7
# Enter time in hours: 6
# Temperature for user-input coefficients at time 6.0 hours: 187.0

# %%
#Single set User Input for Weather Modeling
import matplotlib.pyplot as plt
def temperature_modeling(a, b, c, time):
    temperature = a * time**2 + b * time + c
    return temperature
print("User Input for Weather Modeling\n")
coefficients = input("Enter coefficients (a, b, c) separated by spaces: ").split()
a_user, b_user, c_user = map(float, coefficients)
time_user = float(input("Enter time in hours:"))
temperature_result = temperature_modeling(a_user, b_user, c_user, time_user)
print("Temperature for user-input coefficients at time", time_user, "hours:", temperature_result)
time_values = range(int(time_user) + 1)
temperature_values = [temperature_modeling(a_user, b_user, c_user, t) for t in time_values]

plt.plot(time_values, temperature_values, label='Temperature Curve')
plt.xlabel('Time (hours)')
plt.ylabel('Temperature')
plt.title('Temperature Modeling for User Input Coefficients')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# User Input for Weather Modeling
#
# Enter coefficients (a, b, c) separated by spaces: 4 7 5
# Enter time in hours:8
# Temperature for user-input coefficients at time 8.0 hours: 317.0
